# %% [markdown]
# <a href="https://colab.research.google.com/github/kittykitty228/-/blob/main/%D0%9A%D0%BE%D1%80%D0%BD%D0%B0%D0%B5%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Установка и загрузка библиотек

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
from fastai.vision.all import*
import cv2
from google.colab.patches import cv_imshow

# %% [markdown]
# #Исходные данные

# %% [markdown]
# ##Настройки
# Визуализация

# %%
#Визуализация
fig_size = (5,5)
img_map = 'gray' 
img_slice = [0, 100, 0, 100]

# %% [markdown]
# ##Путь

# %%
path = Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc')
path
# Out:
# Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc')

# %% [markdown]
# ##Чтение содержимого папки

# %%
fnames = get_image_files(path)
fnames
# Out:
# (#100) [Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000007.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000014.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000003.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000037.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000042.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000038.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000012.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000030.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000005.png'),Path('/content/gdrive/MyDrive/питон корнаев 2/lmg_f_16.02.2022_2p5_gc/img1_000000000000039.png')...]

# %%
len(fnames)
# Out:
# 100

# %% [markdown]
# #

# %% [markdown]
# #Вывод изображения на экран

# %% [markdown]
# ##С помощью библиотеки PIL (Python Imaging Library)

# %%
img = Image.open(fnames[0])
#img

# %% [markdown]
# ##С помощью numpy (np), opencv(cv2) и mathplotlib(plt)

# %%
img1 = np.uint32(cv2.imread(str(fnames[0])))
img1.shape, type(img1)
# Out:
# ((1000, 1000, 3), numpy.ndarray)

# %%
plt.figure(figsize = (fig_size[0]*3, fig_size[1]))
plt.subplot(1,3,1)
plt.imshow(img1[:,:,0], cmap = img_map)
plt.title('blue filter')
plt.figure(figsize = (fig_size[0]*3, fig_size[1]))
plt.subplot(1,3,2)
plt.imshow(img1[:,:,1], cmap = img_map)
plt.title('green filter')
plt.figure(figsize = (fig_size[0]*3, fig_size[1]))
plt.subplot(1,3,3)
plt.imshow(img1[:,:,2], cmap = img_map)
plt.title('red filter')
# Out:
# Text(0.5, 1.0, 'red filter')
